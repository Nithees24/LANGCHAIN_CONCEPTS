# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithees24/LANGCHAIN_CONCEPTS/blob/main/CHUNKING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain-text-splitters

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-feb393ec-f013-4c2d-9b83-0f6546e7f8d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-feb393ec-f013-4c2d-9b83-0f6546e7f8d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %pip install -qU langchain-community pymupdf

# %%
# %pip install -qU langchain-community pdfplumber
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 74.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 79.6 MB/s eta 0:00:00

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader("input.pdf")

document = loader.load()

for page_num, page in enumerate(document):
  content = page.page_content.strip()

print(content)
# Out:
# Copyright © 2024 – All rights reserved with Perpetuuiti
#
# 22
# 22
# 2. Primary Finance BC champion (alternate Finance BC champion if Primary
# is unavailable) will keep the CMSC informed about the incident;
# 3. Primary Finance BC champion (alternate Finance BC champion if Primary
# is unavailable) will submit root cause and corrective action for the incident
# and implement any corrective actions approved by CMSC;
# Utilities Unavailability
# BCM Strategy
# Contingency plan strategy for power
# failure, water supply failure, HVAC
# failure, Facility management failure
# etc… is in place
# Power Failure:
# 1. We can use the DG support if the power failure happens.
# 2. Intimate the stakeholder in advance to take alternative actions.
# 3. Regular check-ups to avoid or control the risk
# Water Supply:
# 1. We can call for alternative options if the water supply stops.
# 2. Keep checking the supply regularly to avoid the impact of said
# situation.
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20,length_function=len,is_separator_regex=False)

chunks = text_splitter.split_text(content)

for chunk in chunks:
  print(chunk, "\n")
# Out:
# Copyright © 2024 – All rights reserved with Perpetuuiti
#
# 22
# 22
#
# 22
# 22
# 2. Primary Finance BC champion (alternate Finance BC champion if Primary
#
# is unavailable) will keep the CMSC informed about the incident;
#
# 3. Primary Finance BC champion (alternate Finance BC champion if Primary
#
# is unavailable) will submit root cause and corrective action for the incident
#
# and implement any corrective actions approved by CMSC;
# Utilities Unavailability
# BCM Strategy
#
# BCM Strategy
# Contingency plan strategy for power
# failure, water supply failure, HVAC
#
# failure, Facility management failure
# etc… is in place
# Power Failure:
#
# Power Failure:
# 1. We can use the DG support if the power failure happens.
#
# 2. Intimate the stakeholder in advance to take alternative actions.
#
# 3. Regular check-ups to avoid or control the risk
# Water Supply:
#
# Water Supply:
# 1. We can call for alternative options if the water supply stops.
#
# ...
